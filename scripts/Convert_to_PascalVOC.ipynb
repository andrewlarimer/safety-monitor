# %%
from pascal_voc_writer import Writer
import xml.etree.cElementTree as ET
import os
import pandas as pd
import numpy as np

# %% [markdown]
# ### Function to write in Pascal VOC format

# %%
def write_pascal_voc(element_list, subelement_list):
    """
    function defined to convert the values fed as parameters into 
    Pascal VOC format.  The output is saved into 'Pascal_VOC_Annotaions'
    folder.
    
    Input: 
    element_list: list of all elements that form the header information
    subelement_list: list of sub-elements that correspond to each label
    
    The elements correspond to:
    name:   file name
    width:  width of the image
    height: height of the image
    
    The sub-elements correspond to:
    label: the label in context of annotation
    xmin: x-min attribute of the bounding box
    ymin: y-min attribute of the bounding box
    xmax: x-max attribute of the bounding box
    ymax: y-max attribute of the bounding box
    
    This function essentially writes the output in Pascal VOC format and saves to folder
    """

    for elem in element_list:
        filename=elem['name']
        keylist = [filename]
        sub = list(filter(lambda d:d['name'] in keylist, subelement_list))

        # set the file name of the output file that holds the annotation
        output_file = 'Pascal_VOC_Annotations/' + filename.replace('.jpeg','') + '.xml'
        
        # form the writer object and capture the header level information
        writer = Writer(filename, elem['width'], elem['height'])
        
        # loop through the sub-elements to write the bounding box details for each label
        for s in sub:
            writer.addObject(s['label'], s['xtl'], s['ytl'], s['xbr'], s['ybr'])

        writer.save(output_file)

# %% [markdown]
# ### Function to Parse XML (CVAT Anotation)

# %%
def parse_xml(xml_file_name):
    tree = ET.parse(xml_file_name)  
    root = tree.getroot()
    elem_list=[]
    subelem_list=[]
    
    for elems in root:
        if (elems.attrib.get('id') != None):
            elem_list.append({'name': elems.attrib.get('name'),
                             'width': elems.attrib.get('width'),
                             'height': elems.attrib.get('height')})
            #print("elem_list: ",elem_list)
            
            for subelem in elems:
                if (subelem.attrib.get('label') != None):
                    subelem_list.append({'name': elems.attrib.get('name'),
                                        'label': subelem.attrib.get('label'),
                                        'xtl': subelem.attrib.get('xtl'),
                                        'ytl': subelem.attrib.get('ytl'),
                                        'xbr': subelem.attrib.get('xbr'),
                                        'ybr': subelem.attrib.get('ybr')})
                    
    return elem_list, subelem_list

# %%
elem_list, subelem_list = parse_xml('CVAT-Annotations/construction_annotations_v2.xml')
write_pascal_voc(elem_list, subelem_list)

# %% [markdown]
# ### Generate 'dataset.txt' file

# %%
file=open("dataset.txt", "w")

for elem in elem_list:
    filename=elem['name']
    #print(filename)
    keylist = [filename]
    sub = list(filter(lambda d:d['name'] in keylist, subelem_list))
    write_lst = []

    # capture contents to write to file
    write_lst.append(filename)

    # loop through the sub-elements to write the bounding box details for each label
    for s in sub:
        write_lst.append(s['xtl'])
        write_lst.append(s['ytl'])
        write_lst.append(s['xbr'])
        write_lst.append(s['ybr'])
        write_lst.append(s['label'])

    file.writelines(' '.join(write_lst))
    file.writelines('\n')

file.close()
# Out:
# Sequence01_0.jpeg
# Sequence01_1.jpeg
# Sequence01_10.jpeg
# Sequence01_11.jpeg
# Sequence01_12.jpeg
# Sequence01_13.jpeg
# Sequence01_14.jpeg
# Sequence01_15.jpeg
# Sequence01_16.jpeg
# Sequence01_17.jpeg
# Sequence01_18.jpeg
# Sequence01_19.jpeg
# Sequence01_2.jpeg
# Sequence01_20.jpeg
# Sequence01_21.jpeg
# Sequence01_22.jpeg
# Sequence01_23.jpeg
# Sequence01_24.jpeg
# Sequence01_25.jpeg
# Sequence01_26.jpeg
# Sequence01_27.jpeg
# Sequence01_28.jpeg
# Sequence01_29.jpeg
# Sequence01_3.jpeg
# Sequence01_30.jpeg
# Sequence01_31.jpeg
# Sequence01_32.jpeg
# Sequence01_33.jpeg
# Sequence01_34.jpeg
# Sequence01_35.jpeg
# Sequence01_36.jpeg
# Sequence01_37.jpeg
# Sequence01_38.jpeg
# Sequence01_39.jpeg
# Sequence01_4.jpeg
# Sequence01_40.jpeg
# Sequence01_41.jpeg
# Sequence01_42.jpeg
# Sequence01_43.jpeg
# Sequence01_44.jpeg
# Sequence01_45.jpeg
# Sequence01_46.jpeg
# Sequence01_47.jpeg
# Sequence01_48.jpeg
# Sequence01_49.jpeg
# Sequence01_5.jpeg
# Sequence01_50.jpeg
# Sequence01_51.jpeg
# Sequence01_52.jpeg
# Sequence01_53.jpeg
# Sequence01_54.jpeg
# Sequence01_55.jpeg
# Sequence01_56.jpeg
# Sequence01_57.jpeg
# Sequence01_58.jpeg
# Sequence01_59.jpeg
# Sequence01_6.jpeg
# Sequence01_60.jpeg
# Sequence01_61.jpeg
# Sequence01_62.jpeg
# Sequence01_63.jpeg
# Sequence01_64.jpeg
# Sequence01_65.jpeg
# Sequence01_66.jpeg
# Sequence01_67.jpeg
# Sequence01_7.jpeg
# Sequence01_8.jpeg
# Sequence01_9.jpeg
# Sequence02_100.jpeg
# Sequence02_101.jpeg
# Sequence02_102.jpeg
# Sequence02_103.jpeg
# Sequence02_104.jpeg
# Sequence02_105.jpeg
# Sequence02_106.jpeg
# Sequence02_107.jpeg
# Sequence02_108.jpeg
# Sequence02_109.jpeg
# Sequence02_110.jpeg
# Sequence02_111.jpeg
# Sequence02_112.jpeg
# Sequence02_113.jpeg
# Sequence02_114.jpeg
# Sequence02_115.jpeg
# Sequence02_116.jpeg
# Sequence02_117.jpeg
# Sequence02_118.jpeg
# Sequence02_119.jpeg
# Sequence02_120.jpeg
# Sequence02_121.jpeg
# Sequence02_122.jpeg
# Sequence02_123.jpeg
# Sequence02_124.jpeg
# Sequence02_68.jpeg
# Sequence02_69.jpeg
# Sequence02_70.jpeg
# Sequence02_71.jpeg
# Sequence02_72.jpeg
# Sequence02_73.jpeg
# Sequence02_74.jpeg
# Sequence02_75.jpeg
# Sequence02_76.jpeg
# Sequence02_77.jpeg
# Sequence02_78.jpeg
# Sequence02_79.jpeg
# Sequence02_80.jpeg
# Sequence02_81.jpeg
# Sequence02_82.jpeg
# Sequence02_83.jpeg
# Sequence02_84.jpeg
# Sequence02_85.jpeg
# Sequence02_86.jpeg
# Sequence02_87.jpeg
# Sequence02_88.jpeg
# Sequence02_89.jpeg
# Sequence02_90.jpeg
# Sequence02_91.jpeg
# Sequence02_92.jpeg
# Sequence02_93.jpeg
# Sequence02_94.jpeg
# Sequence02_95.jpeg
# Sequence02_96.jpeg
# Sequence02_97.jpeg
# Sequence02_98.jpeg
# Sequence02_99.jpeg
# Sequence03_125.jpeg
# Sequence03_126.jpeg
# Sequence03_127.jpeg
# Sequence03_128.jpeg
# Sequence03_129.jpeg
# Sequence03_130.jpeg
# Sequence03_131.jpeg
# Sequence03_132.jpeg
# Sequence03_133.jpeg
# Sequence03_134.jpeg
# Sequence03_135.jpeg
# Sequence03_136.jpeg
# Sequence03_137.jpeg
# Sequence03_138.jpeg
# Sequence03_139.jpeg
# Sequence03_140.jpeg
# Sequence03_141.jpeg
# Sequence03_142.jpeg
# Sequence03_143.jpeg
# Sequence03_144.jpeg
# Sequence03_145.jpeg
# Sequence03_146.jpeg
# Sequence03_147.jpeg
# Sequence03_148.jpeg
# Sequence03_151.jpeg
# Sequence03_152.jpeg
# Sequence03_154.jpeg
# Sequence03_155.jpeg
# Sequence03_156.jpeg
# Sequence03_157.jpeg
# Sequence03_158.jpeg
# Sequence03_159.jpeg
# Sequence03_160.jpeg
# Sequence03_161.jpeg
# Sequence03_162.jpeg
# Sequence03_163.jpeg
# Sequence03_164.jpeg
# Sequence03_165.jpeg
# Sequence03_166.jpeg
# Sequence03_167.jpeg
# Sequence03_168.jpeg
# Sequence03_169.jpeg
# Sequence03_170.jpeg
# Sequence03_171.jpeg
# Sequence03_172.jpeg
# Sequence03_173.jpeg
# Sequence03_174.jpeg
# Sequence03_175.jpeg
# Sequence03_176.jpeg
# Sequence03_177.jpeg
# Sequence03_178.jpeg
# Sequence03_179.jpeg
# Sequence03_180.jpeg
# Sequence03_181.jpeg
# Sequence03_182.jpeg
# Sequence03_183.jpeg
# Sequence03_184.jpeg
# Sequence04_185.jpeg
# Sequence04_186.jpeg
# Sequence04_187.jpeg
# Sequence04_188.jpeg
# Sequence04_189.jpeg
# Sequence04_190.jpeg
# Sequence04_191.jpeg
# Sequence04_192.jpeg
# Sequence04_193.jpeg
# Sequence04_194.jpeg
# Sequence05_195.jpeg
# Sequence05_196.jpeg
# Sequence05_197.jpeg
# Sequence05_198.jpeg
# Sequence05_199.jpeg
# Sequence05_200.jpeg
# Sequence05_201.jpeg
# Sequence05_202.jpeg
# Sequence05_203.jpeg
# Sequence05_204.jpeg
# Sequence05_205.jpeg
# Sequence05_206.jpeg
# Sequence05_207.jpeg
# Sequence05_208.jpeg
# Sequence05_209.jpeg
# Sequence05_210.jpeg
# Sequence05_211.jpeg
# Sequence05_212.jpeg
# Sequence06_213.jpeg
# Sequence06_214.jpeg
# Sequence06_215.jpeg
# Sequence06_216.jpeg
# Sequence06_217.jpeg
# Sequence06_218.jpeg
# Sequence06_219.jpeg
# Sequence06_220.jpeg
# Sequence06_221.jpeg
# Sequence06_222.jpeg
# Sequence06_223.jpeg
# Sequence06_224.jpeg
# Sequence06_225.jpeg
# Sequence06_226.jpeg
# Sequence06_227.jpeg
# Sequence06_228.jpeg
# Sequence06_229.jpeg
# Sequence06_230.jpeg
# Sequence06_231.jpeg
# Sequence06_232.jpeg
# Sequence06_233.jpeg
# Sequence06_234.jpeg
# Sequence06_235.jpeg
# Sequence06_236.jpeg
# Sequence06_237.jpeg
# Sequence06_238.jpeg
# Sequence06_239.jpeg
# Sequence06_240.jpeg
# Sequence06_241.jpeg
# Sequence06_242.jpeg
# Sequence06_243.jpeg
# Sequence06_244.jpeg
# Sequence06_245.jpeg
# Sequence06_246.jpeg
# Sequence06_247.jpeg
# Sequence06_248.jpeg
# Sequence06_249.jpeg
# Sequence06_250.jpeg
# Sequence06_251.jpeg
# Sequence06_252.jpeg
# Sequence06_253.jpeg
# Sequence06_254.jpeg
# Sequence06_255.jpeg
# Sequence06_256.jpeg
# Sequence06_257.jpeg
# Sequence06_258.jpeg
# Sequence06_259.jpeg
# Sequence06_260.jpeg
# Sequence06_261.jpeg
# Sequence06_262.jpeg
# Sequence06_263.jpeg
# Sequence06_264.jpeg
# Sequence06_265.jpeg
# Sequence06_266.jpeg
# Sequence06_267.jpeg
# Sequence06_268.jpeg
# Sequence06_269.jpeg
# Sequence06_270.jpeg
# Sequence06_271.jpeg
# Sequence06_272.jpeg
# Sequence06_273.jpeg
# Sequence06_274.jpeg
# Sequence06_275.jpeg
# Sequence06_276.jpeg
# Sequence06_277.jpeg
# Sequence06_278.jpeg
# Sequence07_279.jpeg
# Sequence07_280.jpeg
# Sequence07_281.jpeg
# Sequence07_282.jpeg
# Sequence07_283.jpeg
# Sequence07_284.jpeg
# Sequence07_285.jpeg
# Sequence07_286.jpeg
# Sequence07_287.jpeg
# Sequence07_288.jpeg
# Sequence07_289.jpeg
# Sequence07_290.jpeg
# Sequence07_291.jpeg
# Sequence07_292.jpeg
# Sequence07_293.jpeg
# Sequence07_294.jpeg
# Sequence07_295.jpeg
# Sequence07_296.jpeg
# Sequence07_297.jpeg
# Sequence07_298.jpeg
# Sequence07_299.jpeg
# Sequence07_300.jpeg
# Sequence07_301.jpeg
# Sequence07_302.jpeg
# Sequence07_303.jpeg
# Sequence07_304.jpeg
# Sequence07_305.jpeg
# Sequence07_306.jpeg
# Sequence07_307.jpeg
# Sequence07_308.jpeg
# Sequence07_309.jpeg
# Sequence07_310.jpeg
# Sequence07_311.jpeg
# Sequence07_312.jpeg
# Sequence07_313.jpeg
# Sequence07_314.jpeg
# Sequence07_315.jpeg
# Sequence07_316.jpeg
# Sequence07_317.jpeg
# Sequence07_318.jpeg
# Sequence07_319.jpeg
# Sequence07_320.jpeg
# Sequence07_321.jpeg
# Sequence07_322.jpeg
# Sequence07_323.jpeg
# Sequence07_324.jpeg
# Sequence07_325.jpeg
# Sequence07_326.jpeg
# Sequence07_327.jpeg
# Sequence07_328.jpeg
# Sequence07_329.jpeg
# Sequence07_330.jpeg
# Sequence07_331.jpeg
# Sequence07_332.jpeg
# Sequence07_333.jpeg
# Sequence07_334.jpeg
# Sequence07_335.jpeg
# Sequence07_336.jpeg
# Sequence07_337.jpeg
# Sequence07_338.jpeg
# Sequence07_339.jpeg
# Sequence07_340.jpeg
# Sequence07_341.jpeg
# Sequence07_342.jpeg
# Sequence07_343.jpeg
# Sequence07_344.jpeg
# Sequence07_345.jpeg
# Sequence07_346.jpeg
# Sequence07_347.jpeg
# Sequence07_348.jpeg
# Sequence07_349.jpeg
# Sequence07_350.jpeg
# Sequence07_351.jpeg
# Sequence07_352.jpeg
# Sequence08_353.jpeg
# Sequence08_354.jpeg
# Sequence08_355.jpeg
# Sequence08_356.jpeg
# Sequence08_357.jpeg
# Sequence08_358.jpeg
# Sequence08_359.jpeg
# Sequence08_360.jpeg
# Sequence08_361.jpeg
# Sequence08_362.jpeg
# Sequence08_363.jpeg
# Sequence08_364.jpeg
# Sequence08_365.jpeg
# Sequence08_366.jpeg
# Sequence08_367.jpeg
# Sequence08_368.jpeg
# Sequence08_369.jpeg
# Sequence08_370.jpeg
# Sequence08_371.jpeg
# Sequence08_372.jpeg
# Sequence08_373.jpeg
# Sequence08_375.jpeg
# Sequence08_376.jpeg
# Sequence08_379.jpeg
# Sequence08_381.jpeg
# Sequence08_383.jpeg
# Sequence08_385.jpeg
# Sequence08_386.jpeg
# Sequence08_387.jpeg
# Sequence08_388.jpeg
# Sequence08_389.jpeg
# Sequence08_391.jpeg
# Sequence08_392.jpeg
# Sequence08_393.jpeg
# Sequence08_394.jpeg
# Sequence08_395.jpeg
# Sequence08_396.jpeg
# Sequence08_397.jpeg
# Sequence08_398.jpeg
# Sequence08_399.jpeg
# Sequence08_400.jpeg
# Sequence08_401.jpeg
# Sequence08_402.jpeg
# Sequence08_403.jpeg
# Sequence08_404.jpeg
# Sequence08_405.jpeg
# Sequence08_407.jpeg
# Sequence08_408.jpeg
# Sequence08_409.jpeg
# Sequence08_410.jpeg
# Sequence08_411.jpeg
# Sequence08_412.jpeg
# Sequence08_413.jpeg
# Sequence08_415.jpeg
# Sequence08_416.jpeg
# Sequence08_417.jpeg
# Sequence08_418.jpeg
# Sequence08_419.jpeg
# Sequence08_420.jpeg
# Sequence09_421.jpeg
# Sequence09_422.jpeg
# Sequence09_423.jpeg
# Sequence09_424.jpeg
# Sequence09_427.jpeg
# Sequence09_428.jpeg
# Sequence09_430.jpeg
# Sequence09_431.jpeg
# Sequence09_432.jpeg
# Sequence09_433.jpeg
# Sequence09_434.jpeg
# Sequence09_435.jpeg
# Sequence09_436.jpeg
# Sequence09_437.jpeg
# Sequence09_438.jpeg
# Sequence09_439.jpeg
# Sequence09_440.jpeg
# Sequence09_441.jpeg
# Sequence09_442.jpeg
# Sequence09_443.jpeg
# Sequence09_445.jpeg
# Sequence09_446.jpeg
# Sequence09_450.jpeg
# Sequence09_451.jpeg
# Sequence09_452.jpeg
# Sequence09_453.jpeg
# Sequence09_454.jpeg
# Sequence09_455.jpeg
# Sequence09_456.jpeg
# Sequence09_457.jpeg
# Sequence09_462.jpeg
# Sequence09_463.jpeg
# Sequence09_464.jpeg
# Sequence09_466.jpeg
# Sequence09_468.jpeg
# Sequence09_469.jpeg
# Sequence09_471.jpeg
# Sequence09_472.jpeg
# Sequence09_474.jpeg
# Sequence09_475.jpeg
# Sequence09_476.jpeg
# Sequence09_477.jpeg
# Sequence09_478.jpeg
# Sequence09_479.jpeg
# Sequence09_480.jpeg
# Sequence09_481.jpeg
# Sequence09_482.jpeg
# Sequence09_483.jpeg
# Sequence09_484.jpeg
# Sequence09_485.jpeg
# Sequence09_487.jpeg
# Sequence09_488.jpeg
# Sequence09_489.jpeg
# Sequence09_490.jpeg
# Sequence10_492.jpeg
# Sequence10_493.jpeg
# Sequence10_495.jpeg
# Sequence10_496.jpeg
# Sequence10_497.jpeg
# Sequence10_498.jpeg
# Sequence10_499.jpeg
# Sequence10_500.jpeg
# Sequence10_501.jpeg
# Sequence10_502.jpeg
# Sequence10_503.jpeg
# Sequence10_504.jpeg
# Sequence10_505.jpeg
# Sequence10_506.jpeg
# Sequence10_507.jpeg
# Sequence10_508.jpeg
# Sequence10_510.jpeg
# Sequence10_511.jpeg
# Sequence10_512.jpeg
# Sequence10_513.jpeg
# Sequence10_514.jpeg
# Sequence10_516.jpeg
# Sequence10_517.jpeg
# Sequence10_518.jpeg
# Sequence10_519.jpeg
# Sequence10_520.jpeg
# Sequence10_521.jpeg
# Sequence10_522.jpeg
# Sequence10_523.jpeg
# Sequence10_524.jpeg
# Sequence10_525.jpeg
# Sequence10_526.jpeg
# Sequence10_527.jpeg
# Sequence10_528.jpeg
# Sequence10_530.jpeg
# Sequence10_531.jpeg
# Sequence10_532.jpeg
# Sequence10_533.jpeg
# Sequence10_534.jpeg
# Sequence10_535.jpeg
# Sequence10_536.jpeg
# Sequence10_537.jpeg
# Sequence10_538.jpeg
# Sequence10_540.jpeg
# Sequence10_541.jpeg
# Sequence10_542.jpeg
# Sequence10_543.jpeg
# Sequence10_544.jpeg
# Sequence10_545.jpeg
# Sequence11_546.jpeg
# Sequence11_547.jpeg
# Sequence11_548.jpeg
# Sequence11_549.jpeg
# Sequence11_550.jpeg
# Sequence11_551.jpeg
# Sequence11_552.jpeg
# Sequence11_553.jpeg
# Sequence11_554.jpeg
# Sequence11_556.jpeg
# Sequence11_557.jpeg
# Sequence11_558.jpeg
# Sequence11_559.jpeg
# Sequence11_560.jpeg
# Sequence11_562.jpeg
# Sequence11_563.jpeg
# Sequence11_564.jpeg
# Sequence11_565.jpeg
# Sequence11_566.jpeg
# Sequence11_567.jpeg
# Sequence11_568.jpeg
# Sequence11_569.jpeg
# Sequence11_570.jpeg
# Sequence11_571.jpeg
# Sequence11_572.jpeg
# Sequence11_574.jpeg
# Sequence11_575.jpeg
# Sequence11_578.jpeg
# Sequence11_580.jpeg
# Sequence11_581.jpeg
# Sequence11_582.jpeg
# Sequence11_583.jpeg
# Sequence11_584.jpeg
# Sequence11_585.jpeg
# Sequence11_586.jpeg
# Sequence11_587.jpeg
# Sequence11_588.jpeg
# Sequence11_589.jpeg
# Sequence11_590.jpeg
# Sequence11_591.jpeg
# Sequence11_592.jpeg
# Sequence11_593.jpeg
# Sequence11_595.jpeg
# Sequence11_596.jpeg
# Sequence11_597.jpeg
# Sequence11_598.jpeg
# Sequence11_599.jpeg
# Sequence11_600.jpeg
# Sequence12_601.jpeg
# Sequence12_602.jpeg
# Sequence12_603.jpeg
# Sequence12_604.jpeg
# Sequence12_606.jpeg
# Sequence12_609.jpeg
# Sequence12_610.jpeg
# Sequence12_611.jpeg
# Sequence12_612.jpeg
# Sequence12_614.jpeg
# Sequence12_617.jpeg
# Sequence12_618.jpeg
# Sequence12_620.jpeg
# Sequence12_621.jpeg
# Sequence12_622.jpeg
# Sequence12_623.jpeg
# Sequence12_624.jpeg
# Sequence12_625.jpeg
# Sequence12_626.jpeg
# Sequence12_627.jpeg
# Sequence12_628.jpeg
# Sequence12_629.jpeg
# Sequence12_630.jpeg
# Sequence12_631.jpeg
# Sequence12_632.jpeg
# Sequence12_633.jpeg
# Sequence12_634.jpeg
# Sequence12_635.jpeg
# Sequence12_636.jpeg
# Sequence12_637.jpeg
# Sequence12_638.jpeg
# Sequence12_639.jpeg
# Sequence12_640.jpeg
# Sequence12_641.jpeg
# Sequence12_643.jpeg
# Sequence12_644.jpeg
# Sequence12_645.jpeg
# Sequence12_646.jpeg
# Sequence12_647.jpeg
# Sequence12_648.jpeg
# Sequence12_649.jpeg
# Sequence12_651.jpeg
# Sequence13_652.jpeg
# Sequence13_653.jpeg
# Sequence13_654.jpeg
# Sequence13_655.jpeg
# Sequence13_656.jpeg
# Sequence13_657.jpeg
# Sequence13_659.jpeg
# Sequence13_662.jpeg
# Sequence13_663.jpeg
# Sequence13_664.jpeg
# Sequence13_665.jpeg
# Sequence13_666.jpeg
# Sequence13_667.jpeg
# Sequence13_668.jpeg
# Sequence13_669.jpeg
# Sequence13_670.jpeg
# Sequence13_671.jpeg
# Sequence13_672.jpeg
# Sequence13_673.jpeg
# Sequence13_675.jpeg
# Sequence13_676.jpeg
# Sequence13_677.jpeg
# Sequence13_678.jpeg
# Sequence13_679.jpeg
# Sequence13_680.jpeg
# Sequence13_681.jpeg
# Sequence13_682.jpeg
# Sequence13_683.jpeg
# Sequence13_684.jpeg
# Sequence13_685.jpeg
# Sequence13_686.jpeg
# Sequence13_687.jpeg
# Sequence13_688.jpeg
# Sequence13_690.jpeg
# Sequence13_691.jpeg
# Sequence13_692.jpeg
# Sequence13_693.jpeg
# Sequence13_694.jpeg
# Sequence13_695.jpeg
# Sequence13_696.jpeg
# Sequence13_698.jpeg
# Sequence13_700.jpeg
# Sequence13_701.jpeg
# Sequence13_702.jpeg
# Sequence13_703.jpeg
# Sequence13_704.jpeg
# Sequence13_705.jpeg
# Sequence13_706.jpeg
# Sequence13_707.jpeg
# Sequence13_708.jpeg
# Sequence13_709.jpeg
# Sequence13_710.jpeg
# Sequence13_711.jpeg
# Sequence13_712.jpeg
# Sequence13_713.jpeg
# Sequence13_714.jpeg
# Sequence13_715.jpeg
# Sequence13_716.jpeg
# Sequence13_717.jpeg
# Sequence13_718.jpeg
# Sequence13_719.jpeg
# Sequence13_720.jpeg
# Sequence13_721.jpeg
# Sequence13_722.jpeg
# Sequence13_723.jpeg
# Sequence13_724.jpeg
# Sequence13_725.jpeg
# Sequence13_726.jpeg
# Sequence13_727.jpeg
# Sequence13_728.jpeg
# Sequence13_729.jpeg
# Sequence14_730.jpeg
# Sequence14_731.jpeg
# Sequence14_732.jpeg
# Sequence14_733.jpeg
# Sequence14_734.jpeg
# Sequence14_735.jpeg
# Sequence14_736.jpeg
# Sequence14_737.jpeg
# Sequence14_738.jpeg
# Sequence14_739.jpeg
# Sequence14_740.jpeg
# Sequence14_741.jpeg
# Sequence14_742.jpeg
# Sequence14_743.jpeg
# Sequence14_744.jpeg
# Sequence14_745.jpeg
# Sequence14_746.jpeg
# Sequence14_747.jpeg
# Sequence14_748.jpeg
# Sequence14_749.jpeg
# Sequence14_750.jpeg
# Sequence14_751.jpeg
# Sequence14_752.jpeg
# Sequence14_753.jpeg
# Sequence14_754.jpeg
# Sequence14_755.jpeg
# Sequence14_756.jpeg
# Sequence14_757.jpeg
# Sequence14_758.jpeg
# Sequence14_759.jpeg
# Sequence14_760.jpeg
# Sequence14_761.jpeg
# Sequence14_762.jpeg
# Sequence14_763.jpeg
# Sequence14_764.jpeg
# Sequence14_765.jpeg
# Sequence14_766.jpeg
# Sequence14_767.jpeg
# Sequence14_768.jpeg
# Sequence14_769.jpeg
# Sequence14_770.jpeg
# Sequence14_771.jpeg
# Sequence14_772.jpeg
# Sequence14_773.jpeg
# Sequence14_774.jpeg
# Sequence14_775.jpeg
# Sequence15_777.jpeg
# Sequence15_778.jpeg
# Sequence15_779.jpeg
# Sequence15_780.jpeg
# Sequence15_781.jpeg
# Sequence15_782.jpeg
# Sequence15_783.jpeg
# Sequence15_784.jpeg
# Sequence15_785.jpeg
# Sequence15_786.jpeg
# Sequence15_787.jpeg
# Sequence15_788.jpeg
# Sequence15_789.jpeg
# Sequence15_790.jpeg
# Sequence15_791.jpeg
# Sequence15_792.jpeg
# Sequence15_793.jpeg
# Sequence15_794.jpeg
# Sequence15_795.jpeg
# Sequence15_796.jpeg
# Sequence15_797.jpeg
# Sequence15_798.jpeg
# Sequence15_799.jpeg
# Sequence15_800.jpeg
# Sequence15_801.jpeg
# Sequence15_802.jpeg
# Sequence15_803.jpeg
# Sequence15_804.jpeg
# Sequence15_805.jpeg
# Sequence15_806.jpeg
# Sequence15_807.jpeg
# Sequence15_808.jpeg
# Sequence15_809.jpeg
# Sequence15_810.jpeg
# Sequence15_811.jpeg
# Sequence15_812.jpeg
# Sequence15_813.jpeg
# Sequence15_814.jpeg
# Sequence15_815.jpeg
# Sequence15_816.jpeg
# Sequence15_817.jpeg
# Sequence15_818.jpeg
# Sequence15_819.jpeg
# Sequence15_820.jpeg
# Sequence15_821.jpeg
# Sequence15_822.jpeg
# Sequence15_823.jpeg
# Sequence15_824.jpeg
# Sequence15_825.jpeg
# Sequence16_826.jpeg
# Sequence16_827.jpeg
# Sequence16_828.jpeg
# Sequence16_829.jpeg
# Sequence16_830.jpeg
# Sequence16_832.jpeg
# Sequence16_833.jpeg
# Sequence16_836.jpeg
# Sequence16_837.jpeg
# Sequence16_838.jpeg
# Sequence16_839.jpeg
# Sequence16_840.jpeg
# Sequence16_841.jpeg
# Sequence16_842.jpeg
# Sequence16_843.jpeg
# Sequence16_844.jpeg
# Sequence16_845.jpeg
# Sequence16_851.jpeg
# Sequence16_852.jpeg
# Sequence16_853.jpeg
# Sequence16_854.jpeg
# Sequence16_855.jpeg
# Sequence16_856.jpeg
# Sequence16_857.jpeg
# Sequence16_858.jpeg
# Sequence16_860.jpeg
# Sequence16_861.jpeg
# Sequence16_863.jpeg
# Sequence16_864.jpeg
# Sequence16_865.jpeg
# Sequence16_866.jpeg
# Sequence16_867.jpeg
# Sequence16_868.jpeg
# Sequence16_869.jpeg
# Sequence16_871.jpeg
# Sequence16_872.jpeg
# Sequence16_874.jpeg
# Sequence16_875.jpeg
# Sequence16_876.jpeg
# Sequence16_878.jpeg
# Sequence16_879.jpeg
# Sequence16_881.jpeg
# Sequence16_882.jpeg
# Sequence16_883.jpeg
# Sequence16_884.jpeg
# Sequence17_889.jpeg
# Sequence17_890.jpeg
# Sequence17_891.jpeg
# Sequence17_892.jpeg
# Sequence17_893.jpeg
# Sequence17_894.jpeg
# Sequence17_895.jpeg
# Sequence17_896.jpeg
# Sequence17_897.jpeg
# Sequence17_898.jpeg
# Sequence17_899.jpeg
# Sequence17_900.jpeg
# Sequence17_901.jpeg
# Sequence17_902.jpeg
# Sequence17_903.jpeg
# Sequence17_904.jpeg
# Sequence17_905.jpeg
# Sequence17_906.jpeg
# Sequence17_907.jpeg
# Sequence17_908.jpeg
# Sequence17_909.jpeg
# Sequence17_911.jpeg
# Sequence17_912.jpeg
# Sequence17_913.jpeg
# Sequence17_914.jpeg
# Sequence17_915.jpeg
# Sequence17_916.jpeg
# Sequence17_917.jpeg
# Sequence17_919.jpeg
# Sequence17_920.jpeg
# Sequence17_921.jpeg
# Sequence17_922.jpeg
# Sequence17_923.jpeg
# Sequence17_924.jpeg
# Sequence17_928.jpeg
# Sequence17_929.jpeg
# Sequence17_930.jpeg
# Sequence17_931.jpeg
# Sequence17_932.jpeg
# Sequence17_934.jpeg
# Sequence17_935.jpeg
# Sequence17_936.jpeg
# Sequence17_937.jpeg
# Sequence17_938.jpeg
# Sequence17_939.jpeg
# Sequence17_941.jpeg
# Sequence17_943.jpeg
# Sequence17_944.jpeg
# Sequence17_946.jpeg
# Sequence17_947.jpeg
# Sequence17_949.jpeg
# Sequence17_950.jpeg
# Sequence17_951.jpeg
# Sequence17_952.jpeg
# Sequence17_953.jpeg
# Sequence17_954.jpeg
# Sequence17_955.jpeg
# Sequence17_956.jpeg
# Sequence17_958.jpeg
# Sequence17_959.jpeg
# Sequence17_960.jpeg
# Sequence17_961.jpeg
# Sequence17_962.jpeg
# Sequence17_963.jpeg
# Sequence17_964.jpeg
# Sequence17_965.jpeg
# Sequence17_966.jpeg
# Sequence17_967.jpeg
# Sequence17_969.jpeg
# Sequence17_970.jpeg
# Sequence18_1006.jpeg
# Sequence18_1015.jpeg
# Sequence18_1019.jpeg
# Sequence18_1021.jpeg
# Sequence18_973.jpeg
# Sequence18_975.jpeg
# Sequence18_977.jpeg
# Sequence18_978.jpeg
# Sequence18_981.jpeg
# Sequence18_983.jpeg
# Sequence18_985.jpeg
# Sequence18_987.jpeg
# Sequence18_989.jpeg
# Sequence18_996.jpeg
# Sequence19_1026.jpeg
# Sequence19_1027.jpeg
# Sequence19_1028.jpeg
# Sequence19_1029.jpeg
# Sequence19_1030.jpeg
# Sequence19_1031.jpeg
# Sequence19_1032.jpeg
# Sequence19_1033.jpeg
# Sequence19_1034.jpeg
# Sequence19_1035.jpeg
# Sequence19_1036.jpeg
# Sequence19_1037.jpeg
# Sequence19_1038.jpeg
# Sequence19_1039.jpeg
# Sequence19_1040.jpeg
# Sequence19_1041.jpeg
# Sequence19_1042.jpeg
# Sequence19_1043.jpeg
# Sequence19_1044.jpeg
# Sequence19_1045.jpeg
# Sequence19_1046.jpeg
# Sequence19_1047.jpeg
# Sequence19_1048.jpeg
# Sequence19_1049.jpeg
# Sequence19_1050.jpeg
# Sequence19_1051.jpeg
# Sequence19_1052.jpeg
# Sequence19_1053.jpeg
# Sequence19_1054.jpeg
# Sequence19_1055.jpeg
# Sequence19_1056.jpeg
# Sequence19_1057.jpeg
# Sequence19_1058.jpeg
# Sequence19_1059.jpeg
# Sequence19_1060.jpeg
# Sequence19_1061.jpeg
# Sequence19_1062.jpeg
# Sequence19_1063.jpeg
# Sequence19_1064.jpeg
# Sequence19_1065.jpeg
# Sequence19_1066.jpeg
# Sequence19_1067.jpeg
# Sequence19_1068.jpeg
# Sequence19_1069.jpeg
# Sequence19_1070.jpeg
# Sequence19_1071.jpeg
# Sequence19_1072.jpeg
# Sequence19_1073.jpeg
# Sequence19_1074.jpeg
# Sequence19_1075.jpeg
# Sequence19_1076.jpeg
# Sequence19_1077.jpeg
# Sequence19_1078.jpeg
# Sequence19_1079.jpeg
# Sequence19_1080.jpeg
# Sequence19_1081.jpeg
# Sequence19_1082.jpeg
# Sequence20_1085.jpeg
# Sequence20_1087.jpeg
# Sequence20_1088.jpeg
# Sequence20_1089.jpeg
# Sequence20_1092.jpeg
# Sequence20_1093.jpeg
# Sequence20_1094.jpeg
# Sequence20_1095.jpeg
# Sequence20_1096.jpeg
# Sequence20_1097.jpeg
# Sequence20_1098.jpeg
# Sequence20_1099.jpeg
# Sequence20_1100.jpeg
# Sequence20_1101.jpeg
# Sequence20_1102.jpeg
# Sequence20_1103.jpeg
# Sequence20_1104.jpeg
# Sequence20_1105.jpeg
# Sequence20_1106.jpeg
# Sequence20_1107.jpeg
# Sequence20_1108.jpeg
# Sequence20_1109.jpeg
# Sequence20_1110.jpeg
# Sequence20_1111.jpeg
# Sequence20_1112.jpeg
# Sequence20_1113.jpeg
# Sequence20_1114.jpeg
# Sequence20_1115.jpeg
# Sequence20_1116.jpeg
# Sequence20_1117.jpeg
# Sequence20_1118.jpeg
# Sequence20_1119.jpeg
# Sequence20_1120.jpeg
# Sequence20_1121.jpeg
# Sequence20_1122.jpeg
# Sequence20_1123.jpeg
# Sequence20_1124.jpeg
# Sequence20_1125.jpeg
# Sequence20_1126.jpeg
# Sequence20_1127.jpeg
# Sequence20_1128.jpeg
# Sequence20_1129.jpeg
# Sequence20_1130.jpeg
# Sequence20_1131.jpeg
# Sequence20_1132.jpeg
# Sequence20_1133.jpeg
# Sequence20_1134.jpeg
# Sequence20_1135.jpeg
# Sequence20_1136.jpeg
# Sequence20_1137.jpeg
# Sequence20_1138.jpeg
# Sequence20_1139.jpeg
# Sequence20_1140.jpeg
# Sequence20_1141.jpeg
# Sequence20_1142.jpeg
